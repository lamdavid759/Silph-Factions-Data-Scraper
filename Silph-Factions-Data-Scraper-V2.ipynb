# %% [markdown]
# #### Imports and URLs
# DO NOT EDIT THIS PART UNLESS YOU ARE ADDING A TEAM INTO FACTION INFORMATION

# %%
import requests
from bs4 import BeautifulSoup
import re
import csv
import requests
import time
from ediblepickle import checkpoint
import os
from urllib.parse import quote

# Set-up cache for scraping individual results
cache_dir = 'cache'
if not os.path.exists(cache_dir):
    os.mkdir(cache_dir)

# %%
# Faction Information
factionsURLBase = "https://silph.gg/factions/cycle/season-2-cycle-3-"
factionsTiers = ["iron", "copper", "bronze", "silver", "gold", "platinum", "diamond", "emerald"]
factionsRegions = ["na", "latam", "emea", "apac"]

# Example URL
EmeraldNA = "https://silph.gg/factions/cycle/season-2-cycle-2-emerald-na"

factionHomepages = []

# %%
# Procedurally generate URLs
for tier in factionsTiers: 
    for region in factionsRegions:
        url = factionsURLBase + tier + "-" + region
        get = requests.get(url)
        if get.status_code == 200: factionHomepages.append(url)

#Initializes web scrape of factions in a given tier
def factionInfoScrape(URL):
    URLBase = "https://silph.gg"
    factionNames = []
    factionLinkDict = {}
    factionRosterDict = {}
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")
    for faction in soup.find_all("div",class_="nameWrapper"): 
        factionName = faction.find("p").get_text()
        factionLink = URLBase + faction.find("a").get("href")
        factionNames.append(factionName)
        factionLinkDict[factionName] = factionLink
        factionRoster = []
        factionPage = requests.get(factionLinkDict[factionName])
        factionSoup = BeautifulSoup(factionPage.content, "html.parser")
        for player in factionSoup.findAll(True, {"class":["playerName", "playerName long"]}): 
            factionRoster.append(player.get_text().strip())
        factionRosterDict[factionName] = factionRoster
    return factionRosterDict

# %%
# Function for scraping individual user data, now with a checkpoint for scrapes that fail. This checkpoint will need to be
# deleted after every week, which should be handled in the code below. 
@checkpoint(key=lambda args, kwargs: quote(args[0]) + '.pkl', work_dir=cache_dir)
def individualUserScrape(Username):
    #Variables and Definitions
    URLBase = "https://sil.ph/"
    URL = URLBase + Username

    #Initializes web scrape
    page = requests.get(URL)
        
    soup = BeautifulSoup(page.content, "html.parser")
    silphData = soup.find("div",id="networkAndAchievements")
    if silphData == None: return [] # Checks to see if someone is banned/no longer exists
        
    tournamentResults = silphData.find_all("div",class_="tournament")
    tournamentResultDataHolder = []
    for result in tournamentResults: 
        # Checks if the URL for the given event is a Faction bout and excludes postseason events
        if result.select("a[href*=faction]") == []: continue
        if "Global Melee" in result.find("div",class_="arenaBadge")["title"]: continue
        if "World Championship" in result.find("div",class_="arenaBadge")["title"]: continue

        fact = result.find("a", class_="logo")["title"] # Faction at time of battle
        
        # Conditional formatting to change cupType into proper form, then into database entry
        cupType = result.find("h5", class_="cupType").text.strip().strip("★").strip()
        if "Great" in cupType: cupType = "Great"
        elif "Ultra" in cupType: cupType = "Ultra"
        elif "Master" in cupType: cupType = "Master"    

        # Checks URL for bout information (season, cycle, tier) and region
        boutLink = result.find("a").get("href")
        region = ""
        if "may-2021-qualifiers" in boutLink:
            pattern = "https://silph.gg/factions/cycle/may-2021-qualifiers-(.*)"
            region = re.findall(pattern,boutLink)[0].upper()
            season = 0
            cycle = 1
            tier = "Qualifiers"
        elif "preseason-cycle-2-qualifiers" in boutLink:
            pattern = "https://silph.gg/factions/cycle/preseason-cycle-2-qualifiers-(.*)"
            region = re.findall(pattern,boutLink)[0].upper()
            season = 0
            cycle = 2
            tier = "Qualifiers"
        elif "season-" in boutLink:
            pattern = "https://silph.gg/factions/cycle/season-(.*)-cycle-(.*)-(.*)-(.*)"
            parsedBoutInfo = re.findall(pattern,boutLink)
            season = parsedBoutInfo[0][0]
            cycle = parsedBoutInfo[0][1]
            tier = parsedBoutInfo[0][2].title()
            region = parsedBoutInfo[0][3].upper()
        
        # Manually fixes some inconsistent data parsing
        if region == "": continue
        if region == "EU": region = "EMEA"

        # Checks title for bout number
        boutInfo = result.find("h5", class_="tourneyName").text.strip()
        pattern = "Bout (.*): (.*)"
        parsedBoutNumber = re.findall(pattern,boutInfo)
        #Check to see if this particular bout was part of a promotion/relegation battle
        if parsedBoutNumber[0][1] == "Promotions/Relegations": boutNumber = 8 
        else: boutNumber = int(parsedBoutNumber[0][0])

        record = result.find(class_="win").find("h3", class_="value").text+'-'+result.find(class_="loss").find("h3", class_="value").text

        team = result.find_all(class_="pokemon")
        roster = []
        for mon in team:
            monName = mon["title"]
            #Conditional name edits to massage into proper form
            if monName == 'Armored Mewtwo': monName = 'Mewtwo-Armor'
            elif "Alolan" in monName: monName = monName.replace('Alolan ', '') + '-Alola'
            elif "Galarian" in monName: monName = monName.replace('Galarian ', '') + '-Galar'
            elif "Hisuian" in monName: monName = monName.replace('Hisuian ', '') + '-Hisui'
            elif "Forme" in monName: 
                pattern = '\s\(*'
                result = re.split(pattern,monName)
                monName = result[0]+"-"+result[1]
            elif "Cloak" in monName: 
                pattern = '\s\(*'
                result = re.split(pattern,monName)
                monName = result[0]+"-"+result[1]
            elif "Size" in monName: 
                pattern = '\s\(*'
                result = re.split(pattern,monName)
                monName = result[0]+"-"+result[1]            
            elif "Castform" in monName:
                if "Snowy" in monName: monName = 'Castform-Snowy'
                elif "Rainy" in monName: monName = 'Castform-Rainy'
                elif "Sunny" in monName: monName = 'Castform-Sunny'
                elif "Normal" in monName: monName = 'Castform'                
            if mon.find("img", class_="shadow"): monName = monName + '-S'
            roster.append(monName)
        tournamentResultDataHolder.append([region, tier, fact, Username, cupType, season, cycle, boutNumber, record] + roster)
    return tournamentResultDataHolder

# %% [markdown]
# #### Complete Scrape (COMPUTATIONALLY INTENSIVE)

# %%
# Completely scrape all active factions by determining active rosters and going through all Pokemon teams (even for previous faction membership)
boutData = []
exportedFileName = "Active LATAM Factions Scrape"
for tierLink in factionHomepages:
    factionRosterDict = factionInfoScrape(tierLink)
    for faction in factionRosterDict:
        for member in factionRosterDict[faction]:
            result = individualUserScrape(member)
            for entry in result: boutData.append(entry)
            
with open(exportedFileName+".csv", 'w', encoding="utf-8", newline='') as f:
    write = csv.writer(f)
    write.writerows([["Region", "Tier", "Team", "Player", "Format", "Season", "Cycle", "Bout", "Record", "Team #1", "Team #2", "Team #3", "Team #4", "Team #5", "Team #6"]])        
    write.writerows(boutData)

# %% [markdown]
# #### Partial Scrape for Specific Bouts and Cycles

# %%
# Similar to scrape above, but only writes data to file for given faction bouts
boutData = []
exportedFileName = "S2_C3_B1"
selectedSeason = [2]; 
selectedCycle = [3];
selectedBout = [1];

connection_timeout = 30
for tierLink in factionHomepages:
    factionRosterDict = factionInfoScrape(tierLink)
    for faction in factionRosterDict:
        for member in factionRosterDict[faction]:
            start_time = time.time()
            while True: 
                try: 
                    result = individualUserScrape(member)
                    for entry in result: 
                        if int(entry[5]) in selectedSeason and int(entry[6]) in selectedCycle and int(entry[7]) in selectedBout: 
                            boutData.append(entry)
                    break
                except ConnectionError: 
                    if time.time() > start_time + connection_timeout:
                        raise Exception(f"Unable to connect to {member}'s page after {connection_timeout} seconds of ConnectionErrors")
                    else: 
                        print(f"Unable to connect to {member}'s page. Waiting 1 second before attempting again...")
                        time.sleep(1)
            
            
with open(exportedFileName+".csv", 'w', encoding="utf-8", newline='') as f:
    write = csv.writer(f)
    write.writerows([["Region", "Tier", "Team", "Player", "Format", "Season", "Cycle", "Bout", "Record", "Team #1", "Team #2", "Team #3", "Team #4", "Team #5", "Team #6"]])        
    write.writerows(boutData)

# %% [markdown]
# #### Custom Scrape for Selected Members

# %%
boutData = []
exportedFileName = "ehcityboy"
userList = ["ehcityboy"]
for user in userList:
    result = individualUserScrape(user)
    for entry in result: boutData.append(entry)
with open(exportedFileName+".csv", 'w', encoding="utf-8", newline='') as f:
    write = csv.writer(f)
    write.writerows([["Region", "Tier", "Team", "Player", "Format", "Season", "Cycle", "Bout", "Record", "Team #1", "Team #2", "Team #3", "Team #4", "Team #5", "Team #6"]])        
    write.writerows(boutData)

# %%
with open(exportedFileName+".csv", 'w', encoding="utf-8", newline='') as f:
    write = csv.writer(f)
    write.writerows([["Region", "Tier", "Team", "Player", "Format", "Season", "Cycle", "Bout", "Record", "Team #1", "Team #2", "Team #3", "Team #4", "Team #5", "Team #6"]])        
    write.writerows(boutData)

# %% [markdown]
# ### Prototyping SQL Interfacing

# %%
# %load_ext sql

# %%
# %sql ###

# %%
# %%sql
#
# CREATE TABLE factions_teams (
#     region TEXT,
#     tier TEXT,
#     team TEXT,
#     player TEXT,
#     format TEXT,
#     season INT,
#     cycle INT,
#     bout INT,
#     record TEXT,
#     team_1 TEXT,
#     team_2 TEXT,
#     team_3 TEXT,
#     team_4 TEXT,
#     team_5 TEXT,
#     team_6 TEXT
# );
# Out:
#  * postgresql://postgres:***@factions-database.cxchmfuco7al.us-west-1.rds.amazonaws.com:5432/postgres
# Done.
# []

# %%
import pandas as pd

# %%
results = pd.read_csv("S2_C2_B9.csv", keep_default_na=False)

# %%
results = results.rename(mapper= lambda x: str.lower("".join(x.split(" "))), axis=1)

# %%
results
# Out:
#      region     tier              team           player     format  season  \
# 0        NA     Iron    BraveNerds PVP  Trainer12308866      Great       2
# 1        NA     Iron    BraveNerds PVP  amazednconfused  Celestial       2
# 2        NA     Iron    BraveNerds PVP  SkepticalTracer     Master       2
# 3        NA     Iron    BraveNerds PVP       GinoThanks   Primeval       2
# 4        NA     Iron    BraveNerds PVP      CaspianPike   Primeval       2
# ...     ...      ...               ...              ...        ...     ...
# 1804   APAC  Emerald  Pika Blinders HQ           Pmkd42     Master       2
# 1805   APAC  Emerald  Pika Blinders HQ          Kayne98  Celestial       2
# 1806   APAC  Emerald  Pika Blinders HQ          Jim2504  Sorcerous       2
# 1807   APAC  Emerald  Pika Blinders HQ      rohitashwyo   Primeval       2
# 1808   APAC  Emerald  Pika Blinders HQ       iMrSingh27   Timeless       2
#
#       cycle  bout record                         team#1           team#2  \
# 0         2     9    2-1                      Registeel          Altaria
# 1         2     9    2-1                      Drapion-S        Dragonite
# 2         2     9    3-0  Zacian (Hero of Many Battles)  Giratina-Origin
# 3         2     9    2-1                      Dragonair          Lanturn
# 4         2     9    0-3                      Dragonair          Lanturn
# ...     ...   ...    ...                            ...              ...
# 1804      2     9    1-2                         Dialga        Excadrill
# 1805      2     9    2-1                      Muk-Alola        Cresselia
# 1806      2     9    1-2                     Beedrill-S         Froslass
# 1807      2     9    3-0                      Dragonair         Froslass
# 1808      2     9    1-2                         Lapras          Lanturn
#
#          team#3     team#4     team#5                         team#6
# 0     Lickitung  Azumarill  Toxicroak                       Swampert
# 1     Snorlax-S     Dialga    Miltank                       Regirock
# 2        Mewtwo   Genesect  Dragonite                      Excadrill
# 3       Cradily   Froslass    Malamar                      Muk-Alola
# 4       Cradily   Froslass    Malamar                      Muk-Alola
# ...         ...        ...        ...                            ...
# 1804   Rayquaza    Pikachu   Swampert  Zacian (Hero of Many Battles)
# 1805   Regirock   Empoleon   Greedent                         Flygon
# 1806    Malamar    Hypno-S   Greedent                       Dragalge
# 1807    Dedenne     Regice   Zweilous                        Lanturn
# 1808   Swampert   Skuntank  Abomasnow                     Cofagrigus
#
# [1809 rows x 15 columns]

# %%
63%7
# Out:
# 0

# %%
results.to_sql('factions_teams', conn, if_exists="append", index=False)
# Out:
# 809

# %%
# %%sql
# SELECT *
# FROM factions_teams
# WHERE region = 'NA' and season = 2 and cycle = 2 and bout = 9 and tier = 'Emerald';
# Out:
#  * postgresql://postgres:***@factions-database.cxchmfuco7al.us-west-1.rds.amazonaws.com:5432/postgres
# 69 rows affected.
# [('NA', 'Emerald', 'Evanstonks', 'HollowPurple', 'Great', 2, 2, 9, '1-2', 'Medicham', 'Azumarill', 'Ninetales-Alola', 'Nidoqueen-S', 'Altaria', 'Diggersby'),
#  ('NA', 'Emerald', 'The Body Slammers', 'KingMagikarp314', 'Celestial', 2, 2, 9, '2-1', 'Drapion-S', 'Cresselia', 'Dragalge', 'Empoleon', 'Flygon', 'Regirock'),
#  ('NA', 'Emerald', 'The Body Slammers', 'Pokemonahan89', 'Master', 2, 2, 9, '2-1', 'Mewtwo', 'Groudon', 'Zacian (Hero of Many Battles)', 'Excadrill', 'Primarina', 'Dragonite'),
#  ('NA', 'Emerald', 'The Body Slammers', 'AragornIsMyKing', 'Primeval', 2, 2, 9, '2-1', 'Cradily', 'Aurorus', 'Snorlax', 'Lanturn', 'Froslass', 'Dragonair'),
#  ('NA', 'Emerald', 'The Body Slammers', 'HammadMunir', 'Sorcerous', 2, 2, 9, '3-0', 'Froslass', 'Beedrill-S', 'Dubwool', 'Dunsparce', 'Tentacruel', 'Malamar'),
#  ('NA', 'Emerald', 'The Body Slammers', 'Beelzeboy', 'Primeval', 2, 2, 9, '2-1', 'Tapu Fini', 'Snorlax', 'Froslass', 'Dragonair', 'Haxorus', 'Malamar'),
#  ('NA', 'Emerald', 'The Body Slammers', 'TrentSzcz', 'Timeless', 2, 2, 9, '2-1', 'Beedrill', 'Ninetales', 'Lapras', 'Shiftry', 'Samurott', 'Cofagrigus'),
#  ('NA', 'Emerald', 'The Body Slammers', 'TheBiebsBroTTV', 'Great', 2, 2, 9, '2-1', 'Azumarill', 'Stunfisk-Galar', 'Noctowl', 'Swampert', 'Lickitung', 'Skarmory'),
#  ('NA', 'Emerald', 'PoGoats', 'WindwakerSD', 'Celestial', 2, 2, 9, '2-1', 'Blastoise', 'Cresselia', 'Regirock', 'Drapion-S', 'Gyarados', 'Snorlax'),
#  ('NA', 'Emerald', 'PoGoats', 'MyPikaBestPika', 'Master', 2, 2, 9, '2-1', 'Dialga', 'Zacian (Hero of Many Battles)', 'Mega Blastoise', 'Metagross', 'Gyarados', 'Mamoswine'),
#  ('NA', 'Emerald', 'PoGoats', 'llsemii', 'Great', 2, 2, 9, '2-1', 'Lickitung', 'Tapu Fini', 'Noctowl', 'Froslass', 'Toxicroak', 'Stunfisk-Galar'),
#  ('NA', 'Emerald', 'PoGoats', 'SaadMunir', 'Primeval', 2, 2, 9, '0-3', 'Lapras', 'Dragonair', 'Cradily', 'Tapu Fini', 'Froslass', 'Snorlax'),
#  ('NA', 'Emerald', 'PoGoats', 'HotPoket777', 'Primeval', 2, 2, 9, '2-1', 'Lapras', 'Dragonair', 'Cradily', 'Tapu Fini', 'Froslass', 'Snorlax'),
#  ('NA', 'Emerald', 'PoGoats', 'iSpanD', 'Timeless', 2, 2, 9, '0-3', 'Venusaur', 'Skuntank', 'Cofagrigus', 'Whiscash', 'Lapras', 'Beedrill'),
#  ('NA', 'Emerald', 'PoGoats', 'wdage', 'Sorcerous', 2, 2, 9, '3-0', 'Beedrill-S', 'Azumarill', 'Froslass', 'Haunter', 'Skuntank', 'Dubwool'),
#  ('NA', 'Emerald', 'Stadium Elite', 'IIIPranavIII', 'Great', 2, 2, 9, '2-1', 'Dragalge', 'Ferrothorn', 'Poliwrath', 'Blastoise', 'Pidgeot', 'Sableye'),
#  ('NA', 'Emerald', 'Stadium Elite', 'JEngels21', 'Master', 2, 2, 9, '1-2', 'Gyarados', 'Landorus-Therian', 'Metagross', 'Palkia', 'Togekiss', 'Mega Venusaur'),
#  ('NA', 'Emerald', 'Stadium Elite', 'Arrohh', 'Primeval', 2, 2, 9, '3-0', 'Cradily', 'Aurorus', 'Dragonair', 'Qwilfish-Hisui', 'Froslass', 'Tapu Fini'),
#  ('NA', 'Emerald', 'Stadium Elite', 'Ilqm', 'Sorcerous', 2, 2, 9, '3-0', 'Dubwool', 'Azumarill', 'Froslass', 'Skuntank-S', 'Raichu-Alola', 'Beedrill'),
#  ('NA', 'Emerald', 'Stadium Elite', 'ClashinCliff', 'Celestial', 2, 2, 9, '2-1', 'Cresselia', 'Kingdra', 'Drapion-S', 'Empoleon', 'Regirock', 'Greedent'),
#  ('NA', 'Emerald', 'Stadium Elite', 'ShadowBrady', 'Timeless', 2, 2, 9, '2-1', 'Samurott', 'Shiftry', 'Beedrill', 'Cradily', 'Quagsire', 'Skuntank'),
#  ('NA', 'Emerald', 'Stadium Elite', 'Reis2Occasion', 'Primeval', 2, 2, 9, '1-2', 'Qwilfish-Hisui', 'Tapu Fini', 'Dragonair', 'Lapras', 'Cradily', 'Sudowoodo'),
#  ('NA', 'Emerald', 'Chicago Stars', 'Balk88', 'Great', 2, 2, 9, '3-0', 'Swampert', 'Skarmory', 'Obstagoon', 'Trevenant', 'Froslass', 'Ninetales-Alola'),
#  ('NA', 'Emerald', 'Chicago Stars', 'Zuoken', 'Celestial', 2, 2, 9, '1-2', 'Cresselia', 'Dragalge', 'Greedent', 'Regirock', 'Drapion', 'Samurott'),
#  ('NA', 'Emerald', 'Chicago Stars', 'Uzoukwu', 'Master', 2, 2, 9, '3-0', 'Togekiss', 'Dialga', 'Giratina-Origin', 'Dragonite', 'Snorlax-S', 'Mewtwo'),
#  ('NA', 'Emerald', 'Chicago Stars', 'Abhinav7998', 'Sorcerous', 2, 2, 9, '2-1', 'Froslass', 'Beedrill-S', 'Skuntank', 'Dunsparce', 'Raichu-Alola', 'Dubwool'),
#  ('NA', 'Emerald', 'Chicago Stars', 'Burnobus', 'Timeless', 2, 2, 9, '1-2', 'Samurott', 'Lapras', 'Shiftry', 'Cofagrigus', 'Skuntank', 'Whiscash'),
#  ('NA', 'Emerald', 'Chicago Stars', 'KeenBart', 'Primeval', 2, 2, 9, '1-2', 'Dragonair', 'Froslass', 'Lapras', 'Tyrunt', 'Lanturn', 'Cradily'),
#  ('NA', 'Emerald', 'Chicago Stars', 'Ajv28', 'Primeval', 2, 2, 9, '3-0', 'Froslass', 'Dragonair', 'Lapras', 'Lanturn', 'Cradily', 'Sudowoodo'),
#  ('NA', 'Emerald', 'Ann Arbor Arbok', 'MaiSakurajima2', 'Master', 2, 2, 9, '1-2', 'Mewtwo', 'Giratina-Altered', 'Garchomp', 'Excadrill', 'Dialga', 'Togekiss'),
#  ('NA', 'Emerald', 'Ann Arbor Arbok', 'DijonTheDjinn', 'Primeval', 2, 2, 9, '3-0', 'Snorlax', 'Sudowoodo', 'Cradily', 'Tapu Fini', 'Froslass', 'Lapras'),
#  ('NA', 'Emerald', 'Ann Arbor Arbok', '2016tdouglas', 'Primeval', 2, 2, 9, '1-2', 'Snorlax', 'Dragonair', 'Sudowoodo', 'Cradily', 'Sealeo', 'Froslass'),
#  ('NA', 'Emerald', 'Ann Arbor Arbok', 'ShinyHunterBen', 'Timeless', 2, 2, 9, '3-0', 'Swampert', 'Beedrill', 'Lanturn', 'Shiftry', 'Skuntank', 'Cofagrigus'),
#  ('NA', 'Emerald', 'Ann Arbor Arbok', 'MasterRed', 'Sorcerous', 2, 2, 9, '0-3', 'Hypno-S', 'Dunsparce', 'Froslass', 'Beedrill-S', 'Azumarill', 'Raichu-Alola'),
#  ('NA', 'Emerald', 'Ann Arbor Arbok', 'ShinyDialga45', 'Great', 2, 2, 9, '1-2', 'Lickitung', 'Swampert-S', 'Venusaur', 'Altaria', 'Skarmory', 'Stunfisk-Galar'),
#  ('NA', 'Emerald', 'Ann Arbor Arbok', 'GottaKarchEmAll', 'Celestial', 2, 2, 9, '1-2', 'Drapion-S', 'Cresselia', 'Regirock', 'Snorlax-S', 'Porygon2', 'Empoleon'),
#  ('NA', 'Emerald', 'Final Boss', 'Gucc1G4ng69', 'Great', 2, 2, 9, '0-3', 'Medicham', 'Lickitung', 'Noctowl', 'Azumarill', 'Runerigus', 'Abomasnow-S'),
#  ('NA', 'Emerald', 'Final Boss', 'Panick23', 'Celestial', 2, 2, 9, '2-1', 'Dragalge', 'Miltank', 'Cresselia', 'Cradily', 'Drapion', 'Skarmory'),
#  ('NA', 'Emerald', 'Final Boss', 'HMLondon', 'Master', 2, 2, 9, '0-3', 'Dialga', 'Giratina-Origin', 'Mewtwo', 'Primarina', 'Gyarados', 'Excadrill'),
#  ('NA', 'Emerald', 'Final Boss', '4TheBattles', 'Primeval', 2, 2, 9, '2-1', 'Sealeo', 'Haxorus', 'Cradily', 'Dragonair', 'Snorlax', 'Lapras'),
#  ('NA', 'Emerald', 'Final Boss', 'kreasor', 'Primeval', 2, 2, 9, '0-3', 'Cradily', 'Froslass', 'Dedenne', 'Sealeo', 'Dragonair', 'Snorlax'),
#  ('NA', 'Emerald', 'Final Boss', 'Obedomac', 'Timeless', 2, 2, 9, '2-1', 'Samurott', 'Galvantula', 'Quagsire', 'Skuntank', 'Ninetales', 'Cradily'),
#  ('NA', 'Emerald', 'Final Boss', 'LordCooler', 'Sorcerous', 2, 2, 9, '1-2', 'Froslass', 'Tentacruel', 'Dubwool', 'Azumarill', 'Skuntank', 'Dunsparce'),
#  ('NA', 'Emerald', 'Icy Wind', 'Doonebug97', 'Sorcerous', 2, 2, 9, '2-1', 'Azumarill', 'Froslass', 'Dubwool', 'Dunsparce', 'Skuntank', 'Beedrill-S'),
#  ('NA', 'Emerald', 'Cool Cats', 'CalebPeng', 'Celestial', 2, 2, 9, '1-2', 'Regirock', 'Cresselia', 'Drapion-S', 'Greedent', 'Dragalge', 'Blastoise'),
#  ('NA', 'Emerald', 'Cool Cats', 'PolymersUp', 'Primeval', 2, 2, 9, '2-1', 'Cradily', 'Aurorus', 'Snorlax', 'Froslass', 'Lanturn', 'Dragonair'),
#  ('NA', 'Emerald', 'Cool Cats', 'Twastell', 'Sorcerous', 2, 2, 9, '1-2', 'Beedrill-S', 'Dubwool', 'Tentacruel', 'Dunsparce', 'Froslass', 'Greedent'),
#  ('NA', 'Emerald', 'Cool Cats', 'Hsineerg', 'Primeval', 2, 2, 9, '1-2', 'Dragonair', 'Cradily', 'Greedent', 'Lanturn', 'Sealeo', 'Froslass'),
#  ('NA', 'Emerald', 'Cool Cats', 'Monstars50', 'Master', 2, 2, 9, '2-1', 'Mewtwo', 'Dialga', 'Gyarados', 'Metagross', 'Garchomp', 'Zacian (Hero of Many Battles)'),
#  ('NA', 'Emerald', 'Cool Cats', 'Ramberto777', 'Timeless', 2, 2, 9, '1-2', 'Lapras', 'Shiftry', 'Blaziken', 'Cofagrigus', 'Whiscash', 'Muk'),
#  ('NA', 'Emerald', 'Cool Cats', 'dfhb1dwm', 'Great', 2, 2, 9, '3-0', 'Venusaur-S', 'Lickitung', 'Azumarill', 'Deoxys-Defense', 'Mandibuzz', 'Stunfisk-Galar'),
#  ('NA', 'Emerald', 'Icy Wind', 'x3TheGOAT3x', 'Great', 2, 2, 9, '0-3', 'Venusaur', 'Lickitung', 'Skarmory', 'Swampert', 'Medicham', 'Froslass'),
#  ('NA', 'Emerald', 'Icy Wind', 'ScrapinPete', 'Celestial', 2, 2, 9, '2-1', 'Cresselia', 'Drapion-S', 'Lickilicky', 'Dragalge', 'Miltank', 'Empoleon'),
#  ('NA', 'Emerald', 'Icy Wind', 'Uberjudgement', 'Master', 2, 2, 9, '1-2', 'Mewtwo', 'Giratina-Altered', 'Zacian (Hero of Many Battles)', 'Reshiram', 'Excadrill', 'Gyarados'),
#  ('NA', 'Emerald', 'Icy Wind', 'jaysfan55', 'Timeless', 2, 2, 9, '2-1', 'Lapras', 'Whiscash', 'Shiftry', 'Galvantula', 'Blaziken', 'Ninetales'),
#  ('NA', 'Emerald', 'Icy Wind', 'DragOns1lk', 'Primeval', 2, 2, 9, '2-1', 'Lapras', 'Aurorus', 'Dragonair', 'Cradily', 'Lanturn', 'Greedent'),
#  ('NA', 'Emerald', 'Icy Wind', 'KevinSaludares', 'Primeval', 2, 2, 9, '1-2', 'Greedent', 'Cradily', 'Tapu Fini', 'Lapras', 'Froslass', 'Dragonair'),
#  ('NA', 'Emerald', 'Wing Attack', 'Motiks', 'Great', 2, 2, 9, '1-2', 'Trevenant', 'Lapras', 'Drapion-S', 'Stunfisk', 'Ninetales-S', 'Goodra'),
#  ('NA', 'Emerald', 'Wing Attack', 'x3DxJMar159', 'Celestial', 2, 2, 9, '1-2', 'Cresselia', 'Dragalge', 'Drapion', 'Greedent', 'Empoleon', 'Scizor-S'),
#  ('NA', 'Emerald', 'Wing Attack', 'Rhyblet', 'Sorcerous', 2, 2, 9, '0-3', 'Azumarill', 'Beedrill-S', 'Froslass', 'Raichu-Alola', 'Greedent', 'Dubwool'),
#  ('NA', 'Emerald', 'Wing Attack', 'WinstontheChamp', 'Timeless', 2, 2, 9, '1-2', 'Ariados', 'Swampert', 'Shiftry', 'Magcargo', 'Lapras', 'Cofagrigus'),
#  ('NA', 'Emerald', 'Wing Attack', 'xXRubixMasterXx', 'Primeval', 2, 2, 9, '2-1', 'Tapu Fini', 'Dragonair', 'Muk-Alola', 'Aurorus', 'Munchlax', 'Haxorus'),
#  ('NA', 'Emerald', 'Wing Attack', 'ThngsCATScntEat', 'Primeval', 2, 2, 9, '0-3', 'Lanturn', 'Dragonair', 'Froslass', 'Sealeo', 'Snorlax', 'Cradily'),
#  ('NA', 'Emerald', 'Wing Attack', 'cdub87', 'Master', 2, 2, 9, '2-1', 'Mega Charizard X', 'Palkia', 'Melmetal', 'Gyarados', 'Metagross', 'Florges (Yellow Flower)'),
#  ('NA', 'Emerald', 'Evanstonks', 'Warnerg', 'Celestial', 2, 2, 9, '1-2', 'Drapion-S', 'Dragonite-S', 'Cresselia', 'Politoed-S', 'Greedent', 'Scizor-S'),
#  ('NA', 'Emerald', 'Evanstonks', 'AdamDHS', 'Master', 2, 2, 9, '1-2', 'Giratina-Origin', 'Groudon', 'Lugia', 'Garchomp', 'Genesect', 'Snorlax'),
#  ('NA', 'Emerald', 'Evanstonks', 'leogeo0', 'Sorcerous', 2, 2, 9, '0-3', 'Froslass', 'Dunsparce', 'Raichu-Alola', 'Beedrill-S', 'Dubwool', 'Azumarill'),
#  ('NA', 'Emerald', 'Evanstonks', 'TeddybearXD', 'Primeval', 2, 2, 9, '1-2', 'Lapras', 'Dragonair', 'Sudowoodo', 'Shiftry', 'Cradily', 'Froslass'),
#  ('NA', 'Emerald', 'Evanstonks', 'Bubblewrapper1', 'Timeless', 2, 2, 9, '1-2', 'Venusaur', 'Ariados', 'Cofagrigus', 'Skuntank', 'Lapras', 'Whiscash')]

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('XXX')

# %%
conn = engine.connect()
