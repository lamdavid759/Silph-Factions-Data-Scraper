# %%
import silph_factions_scraper as sf
import pandas as pd
import importlib as imp

# %%
# Reloads module to reflect new changes.
imp.reload(sf);

# %% [markdown]
# ## Individual Look-up Functions
# Enter in a valid Silph username as a string. Case insensitive.

# %%
# Individual player look-up
sf.individual_user_scrape("Maldobola")
# Out:
#   region      tier           faction     player  format  season  cycle  bout  \
# 0  LATAM  Platinum  Capivara Killers  Maldobola  Master       2      4     2
# 1  LATAM  Platinum  Capivara Killers  Maldobola  Master       2      4     1
# 2  LATAM  Platinum  Capivara Killers  Maldobola  Master       2      3     9
# 3  LATAM  Platinum  Capivara Killers  Maldobola  Master       2      3     6
# 4  LATAM  Platinum  Capivara Killers  Maldobola  Master       2      3     5
#
#   record       mon1         mon2            mon3              mon4  \
# 0    1-2  Metagross  Mega Gengar         Xerneas           Snorlax
# 1    2-0   Garchomp       Kyogre  Mega Abomasnow            Dialga
# 2    1-2     Kyogre    Metagross  Mega Salamence           Snorlax
# 3    1-2   Togekiss       Dialga          Kyogre  Landorus-Therian
# 4    2-1        N/A          N/A             N/A               N/A
#
#                                mon5       mon6
# 0                          Gyarados  Dragonite
# 1                          Togekiss  Excadrill
# 2                          Reshiram  Excadrill
# 3  Zamazenta (Hero of Many Battles)   Gyarados
# 4                               N/A        N/A

# %% [markdown]
# ## Scraping Code
# Run the first cell if you wish to start off scraping. Set clear_player_cache = True to ensure that you are not scraping from old Silph cards. If the scrape fails, set clear_player_cache = False to ensure that previously cached results will remain.
#
# If you have a relatively up-to-date .pkl file, you can instead load the .pkl file directly into a DataFrame.

# %%
# Full scrape. Will take ~90 minutes on a personal computer. Code is commented out as to avoid accidentially hitting the Sil.ph site too much. 
results = sf.full_scrape(clear_player_cache=False)
# Out:
# Generating/loading factions rosters...
# 100%|██████████| 8/8 [00:00<00:00, 666.52it/s]
# Generating player Pokemon rosters...
# 100%|██████████| 270/270 [00:42<00:00,  6.36it/s]

# %%
# Alternatively, if an older pickled file exists, load it into pandas. Check the directory for the latest .pkl file.  
results = pd.read_pickle("2023-01-24.pkl")

# %% [markdown]
# ## Filtering Results
# To filter the results, either use built-in pd.DataFrame filtering or use the following steps.
# 1. Generate a list of desired bouts using enumerate_bouts()
# 2. Add filters one at a time using add_filter()
# 3. Use your list of filters to generate a filtered view using subset_results()
#
# You can save the filtered DataFrame by specifying a filename for the save keyword.

# %%
# Generate desired filters
filter_list = sf.enumerate_bouts((2,3,1))
#filter_list = sf.add_filter(filter_list, "faction", "Evanstonks")
#filter_list = sf.add_filter(filter_list, "format", "Master")

# %%
# View filtered results given a list of filters and a results DataFrame. 
sf.subset_results(results, filter_list, save="S2_C3_B6.csv")
# Out:
#    region      tier               faction           player    format season  \
# 10     NA      Open               SubZero   BetsyandCalvin    Master      2
# 8      NA      Open               SubZero  TheBlackluffy92     Ultra      2
# 8      NA      Open               SubZero      OGPlayerOne  Vanguard      2
# 7      NA      Open               SubZero       Capitalyze     Ember      2
# 11     NA  Platinum          HV Pogo Dojo      Vegito42069     Ultra      2
# ..    ...       ...                   ...              ...       ...    ...
# 0    APAC   Emerald  Vellore Victorybells           MMSyed    Arcana      2
# 0    APAC   Emerald  Vellore Victorybells      DeYupFamily    Arcana      2
# 0    APAC   Emerald  Vellore Victorybells        Joevember  Catacomb      2
# 0    APAC   Emerald  Vellore Victorybells         aronicco     Great      2
# 0    APAC   Emerald  Vellore Victorybells    DrAbdulrahman  Catacomb      2
#
#    cycle bout record            mon1        mon2        mon3  \
# 10     3    1    2-1          Mewtwo      Kyogre   Dragonite
# 8      3    1    2-1      Swampert-S   Toxicroak     Umbreon
# 8      3    1    1-2  Castform-Rainy   Machamp-S    Froslass
# 7      3    1    2-1  Qwilfish-Hisui      Gligar   Charizard
# 11     3    1    3-0       Charizard  Swampert-S     Walrein
# ..   ...  ...    ...             ...         ...         ...
# 0      4    3    3-0         Crustle     Shiftry         Mew
# 0      4    3    1-2        Pelipper  Jumpluff-S  Cofagrigus
# 0      4    3    2-1         Umbreon    Beedrill    Skuntank
# 0      4    3    1-2       Drapion-S   Obstagoon    Froslass
# 0      4    3    0-3        Samurott     Umbreon    Jumpluff
#
#                        mon4             mon5           mon6
# 10  Florges (Yellow Flower)         Buzzwole  Mega Ampharos
# 8                 Tapu Fini       Galvantula       Skarmory
# 8                   Swoobat          Mantine       Regirock
# 7                Electivire        Trevenant      Honchkrow
# 11              Abomasnow-S  Giratina-Origin      Tapu Fini
# ..                      ...              ...            ...
# 0                  Pelipper         Jumpluff     Cofagrigus
# 0                   Cradily          Crustle        Malamar
# 0                Barbaracle         Samurott     Chesnaught
# 0                  Pelipper        Registeel      Tapu Fini
# 0                  Skuntank       Barbaracle       Froslass
#
# [22144 rows x 15 columns]
