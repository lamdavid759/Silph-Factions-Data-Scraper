# %%
import silph_factions_scraper as sf
import pandas as pd
import importlib as imp

# %%
# Reloads module to reflect new changes.
imp.reload(sf);

# %% [markdown]
# ## Individual Look-up Functions
# Enter in a valid Silph username as a string. Case insensitive.

# %%
# Individual player look-up
sf.individual_user_scrape("Maldobola")
# Out:
#   region      tier           faction     player  format  season  cycle  bout  \
# 0  LATAM  Platinum  Capivara Killers  Maldobola  Master       2      3     5
#
#   record mon1 mon2 mon3 mon4 mon5 mon6
# 0    2-1  N/A  N/A  N/A  N/A  N/A  N/A

# %% [markdown]
# ## Scraping Code
# Run the first cell if you wish to start off scraping. Set clear_player_cache = True to ensure that you are not scraping from old Silph cards. If the scrape fails, set clear_player_cache = False to ensure that previously cached results will remain.
#
# If you have a relatively up-to-date .pkl file, you can instead load the .pkl file directly into a DataFrame.

# %%
# Full scrape. Will take ~90 minutes on a personal computer. Code is commented out as to avoid accidentially hitting the Sil.ph site too much. 
results = sf.full_scrape(clear_player_cache=False)
# Out:
# 10/270 factions completed. Total elapsed time: 0.0 min.
# 20/270 factions completed. Total elapsed time: 0.0 min.
# 30/270 factions completed. Total elapsed time: 0.01 min.
# 40/270 factions completed. Total elapsed time: 0.01 min.
# 50/270 factions completed. Total elapsed time: 0.02 min.
# 60/270 factions completed. Total elapsed time: 0.03 min.
# 70/270 factions completed. Total elapsed time: 0.04 min.
# 80/270 factions completed. Total elapsed time: 0.05 min.
# 90/270 factions completed. Total elapsed time: 0.07 min.
# 100/270 factions completed. Total elapsed time: 0.09 min.
# 110/270 factions completed. Total elapsed time: 0.1 min.
# 120/270 factions completed. Total elapsed time: 0.12 min.
# 130/270 factions completed. Total elapsed time: 0.15 min.
# 140/270 factions completed. Total elapsed time: 0.17 min.
# 150/270 factions completed. Total elapsed time: 0.2 min.
# 160/270 factions completed. Total elapsed time: 0.23 min.
# 170/270 factions completed. Total elapsed time: 1.29 min.
# 180/270 factions completed. Total elapsed time: 4.7 min.
# 190/270 factions completed. Total elapsed time: 7.6 min.
# 200/270 factions completed. Total elapsed time: 26.01 min.
# 210/270 factions completed. Total elapsed time: 29.74 min.
# 220/270 factions completed. Total elapsed time: 34.01 min.
# 230/270 factions completed. Total elapsed time: 37.69 min.
# 240/270 factions completed. Total elapsed time: 47.39 min.
# 250/270 factions completed. Total elapsed time: 51.53 min.
# 260/270 factions completed. Total elapsed time: 55.28 min.
# 270/270 factions completed. Total elapsed time: 57.99 min.

# %%
# Alternatively, if an older pickled file exists, load it into pandas. Check the directory for the latest .pkl file.  
results = pd.read_pickle("2023-01-24.pkl")

# %% [markdown]
# ## Filtering Results
# To filter the results, either use built-in pd.DataFrame filtering or use the following steps.
# 1. Generate a list of desired bouts using enumerate_bouts()
# 2. Add filters one at a time using add_filter()
# 3. Use your list of filters to generate a filtered view using subset_results()
#
# You can save the filtered DataFrame by specifying a filename for the save keyword.

# %%
# Generate desired filters
filter_list = sf.enumerate_bouts((2,3,5))
#filter_list = sf.add_filter(filter_list, "faction", "Evanstonks")
#filter_list = sf.add_filter(filter_list, "format", "Master")

# %%
# View filtered results given a list of filters and a results DataFrame. 
sf.subset_results(results, filter_list, save="S2_C3_B5.csv")
# Out:
#    region     tier             faction           player    format season  \
# 0      NA     Iron  Pioneer Valley PVP         ThxObama     Great      2
# 0      NA     Iron  Pioneer Valley PVP  Burritohospital     Ultra      2
# 0      NA     Iron  Pioneer Valley PVP     BobbyLeTorch    Master      2
# 0      NA     Iron  Pioneer Valley PVP         Gortakom  Vanguard      2
# 0      NA     Iron  Pioneer Valley PVP        aceslider     Ember      2
# ..    ...      ...                 ...              ...       ...    ...
# 0    APAC  Emerald      PH Brave Birds      franzwithaZ  Vanguard      2
# 0    APAC  Emerald      PH Brave Birds   MasterGeneroso  Vanguard      2
# 0    APAC  Emerald      PH Brave Birds       Mhyzel0409     Ultra      2
# 0    APAC  Emerald      PH Brave Birds        darfreeze     Ember      2
# 0    APAC  Emerald      PH Brave Birds        iKiyoshee     Ember      2
#
#    cycle bout record       mon1           mon2            mon3         mon4  \
# 0      3    5    2-1  Machamp-S        Umbreon         Tropius     Pelipper
# 0      3    5    2-1   Ampharos        Aurorus       Cresselia     Virizion
# 0      3    5    1-2   Nihilego         Kyogre        Gyarados       Kyurem
# 0      3    5    2-1  Walrein-S       Primeape      Cofagrigus  Dragonair-S
# 0      3    5    0-3  Charizard         Gligar  Qwilfish-Hisui    Poliwrath
# ..   ...  ...    ...        ...            ...             ...          ...
# 0      3    5    1-2    Walrein     Swampert-S      Cofagrigus     Dragalge
# 0      3    5    1-2    Mantine        Crustle      Cofagrigus      Kingdra
# 0      3    5    1-2   Guzzlord      Charizard        Drifblim    Registeel
# 0      3    5    1-2     Gligar  Marowak-Alola       Poliwrath    Charizard
# 0      3    5    0-3     Raichu        Victini       Charizard    Mamoswine
#
#               mon5            mon6
# 0         Froslass  Stunfisk-Galar
# 0        Charizard      Escavalier
# 0        Terrakion          Mewtwo
# 0         Regirock         Noctowl
# 0        Piloswine      Electivire
# ..             ...             ...
# 0         Regirock         Noctowl
# 0         Stunfisk          Emolga
# 0         Virizion      Politoed-S
# 0   Qwilfish-Hisui       Piloswine
# 0   Qwilfish-Hisui       Poliwrath
#
# [1877 rows x 15 columns]
