# %%
import silph_factions_scraper as sf
import pandas as pd
import importlib as imp

# %%
# Reloads module to reflect new changes.
imp.reload(sf);

# %% [markdown]
# ## Individual Look-up Functions
# Enter in a valid Silph username as a string. Case insensitive.

# %%
# Individual player look-up
sf.individual_user_scrape("SageShadows")
# Out:
#    region        tier     faction       player         format  season  cycle  \
# 0      NA     Emerald  Evanstonks  SageShadows       Primeval       2      2
# 1      NA     Emerald  Evanstonks  SageShadows         Master       2      1
# 2      NA     Diamond  Evanstonks  SageShadows         Master       1      3
# 3      NA     Diamond  Evanstonks  SageShadows         Master       1      3
# 4      NA     Diamond  Evanstonks  SageShadows         Master       1      3
# 5      NA     Diamond  Evanstonks  SageShadows         Master       1      3
# 6      NA    Platinum  Evanstonks  SageShadows          Comet       1      2
# 7      NA    Platinum  Evanstonks  SageShadows         Master       1      2
# 8      NA    Platinum  Evanstonks  SageShadows          Great       1      2
# 9      NA  Qualifiers  Evanstonks  SageShadows          Great       0      1
# 10     NA  Qualifiers  Evanstonks  SageShadows  Floating City       0      1
#
#     bout record            mon1              mon2        mon3            mon4  \
# 0      9    1-2         Cradily          Froslass   Dragonair         Snorlax
# 1      7    1-2          Kyogre            Dialga    Melmetal       Primarina
# 2      4    1-2        Garchomp          Togekiss       Lugia        Gyarados
# 3      3    0-3          Palkia            Mewtwo     Avalugg        Gyarados
# 4      2    0-3           Lugia  Giratina-Altered   Metagross        Gyarados
# 5      1    2-1          Mewtwo  Giratina-Altered    Gyarados        Togekiss
# 6      7    1-2       Diggersby         Cresselia   Ninetales        Vigoroth
# 7      6    2-1         Sylveon             Lugia      Mewtwo       Mamoswine
# 8      3    2-1  Deoxys-Defense         Azumarill   Diggersby         Sableye
# 9      5    1-2      Galvantula       Abomasnow-S    Medicham  Stunfisk-Galar
# 10     4    1-2        Swampert        Wigglytuff  Ferrothorn        Articuno
#
#           mon5              mon6
# 0    Tapu Fini            Sealeo
# 1     Garchomp  Landorus-Therian
# 2    Excadrill            Mewtwo
# 3    Excadrill         Metagross
# 4    Excadrill           Avalugg
# 5    Excadrill         Magnezone
# 6      Dewgong            Golbat
# 7     Gyarados         Excadrill
# 8   Talonflame        Ferrothorn
# 9      Sableye         Cresselia
# 10    Vigoroth         Charizard

# %% [markdown]
# ## Scraping Code
# Run the first cell if you wish to start off scraping. Set clear_player_cache = True to ensure that you are not scraping from old Silph cards. If the scrape fails, set clear_player_cache = False to ensure that previously cached results will remain.
#
# If you have a relatively up-to-date .pkl file, you can instead load the .pkl file directly into a DataFrame.

# %%
# Full scrape. Will take ~90 minutes on a personal computer. Code is commented out as to avoid accidentially hitting the Sil.ph site too much. 
# results = sf.full_scrape(clear_player_cache=False)
# Out:
# 10/270 factions completed. Total elapsed time: 0.0 min.
# 20/270 factions completed. Total elapsed time: 0.0 min.
# 30/270 factions completed. Total elapsed time: 0.01 min.
# 40/270 factions completed. Total elapsed time: 0.01 min.
# 50/270 factions completed. Total elapsed time: 0.02 min.
# 60/270 factions completed. Total elapsed time: 0.03 min.
# 70/270 factions completed. Total elapsed time: 0.04 min.
# 80/270 factions completed. Total elapsed time: 0.05 min.
# 90/270 factions completed. Total elapsed time: 0.07 min.
# 100/270 factions completed. Total elapsed time: 0.08 min.
# 110/270 factions completed. Total elapsed time: 0.1 min.
# 120/270 factions completed. Total elapsed time: 0.12 min.
# 130/270 factions completed. Total elapsed time: 0.14 min.
# 140/270 factions completed. Total elapsed time: 0.16 min.
# 150/270 factions completed. Total elapsed time: 0.19 min.
# 160/270 factions completed. Total elapsed time: 0.21 min.
# 170/270 factions completed. Total elapsed time: 0.24 min.
# 180/270 factions completed. Total elapsed time: 0.27 min.
# 190/270 factions completed. Total elapsed time: 0.3 min.
# 200/270 factions completed. Total elapsed time: 0.33 min.
# 210/270 factions completed. Total elapsed time: 0.37 min.
# 220/270 factions completed. Total elapsed time: 0.41 min.
# 230/270 factions completed. Total elapsed time: 0.45 min.
# 240/270 factions completed. Total elapsed time: 0.49 min.
# 250/270 factions completed. Total elapsed time: 0.54 min.
# 260/270 factions completed. Total elapsed time: 0.59 min.
# 270/270 factions completed. Total elapsed time: 3.43 min.

# %%
# Alternatively, if an older pickled file exists, load it into pandas. 
results = pd.read_pickle("2022-12-21.pkl")

# %% [markdown]
# ## Filtering Results
# To filter the results, either use built-in pd.DataFrame filtering or use the following steps.
# 1. Generate a list of desired bouts using enumerate_bouts()
# 2. Add filters one at a time using add_filter()
# 3. Use your list of filters to generate a filtered view using subset_results()
#
# You can save the filtered DataFrame by specifying a filename for the save keyword.

# %%
# Generate desired filters
filter_list = sf.enumerate_bouts((2,2,1), (2,2,9))
filter_list = sf.add_filter(filter_list, "faction", "Evanstonks")
filter_list = sf.add_filter(filter_list, "format", "Master")

# %%
# View filtered results given a list of filters and a results DataFrame. 
sf.subset_results(results, filter_list, save=False)
# Out:
#    region     tier     faction   player  format season cycle bout record  \
# 10     NA  Emerald  Evanstonks  AdamDHS  Master      2     2    1    1-2
# 9      NA  Emerald  Evanstonks  AdamDHS  Master      2     2    2    1-2
# 8      NA  Emerald  Evanstonks  AdamDHS  Master      2     2    3    1-2
# 7      NA  Emerald  Evanstonks  AdamDHS  Master      2     2    4    2-1
# 6      NA  Emerald  Evanstonks  AdamDHS  Master      2     2    5    2-1
# 5      NA  Emerald  Evanstonks  AdamDHS  Master      2     2    6    3-0
# 4      NA  Emerald  Evanstonks  AdamDHS  Master      2     2    7    2-1
# 3      NA  Emerald  Evanstonks  AdamDHS  Master      2     2    8    1-2
# 2      NA  Emerald  Evanstonks  AdamDHS  Master      2     2    9    1-2
#
#                              mon1                           mon2  \
# 10                      Dragonite                      Excadrill
# 9                          Mewtwo                         Dialga
# 8                          Mewtwo                         Dialga
# 7   Zacian (Hero of Many Battles)                         Dialga
# 6   Zacian (Hero of Many Battles)                         Dialga
# 5                          Mewtwo                Giratina-Origin
# 4                          Kyogre  Zacian (Hero of Many Battles)
# 3                          Palkia  Zacian (Hero of Many Battles)
# 2                 Giratina-Origin                        Groudon
#
#                              mon3       mon4                    mon5  \
# 10                Giratina-Origin     Mewtwo  Genesect (Chill Drive)
# 9                 Giratina-Origin  Excadrill                Genesect
# 8                          Zekrom  Excadrill                 Snorlax
# 7                           Lugia  Excadrill                Gyarados
# 6                Landorus-Therian  Excadrill                Gyarados
# 5   Zacian (Hero of Many Battles)  Excadrill               Dragonite
# 4                       Excadrill   Garchomp                 Snorlax
# 3                       Excadrill   Garchomp                Genesect
# 2                           Lugia   Garchomp                Genesect
#
#                              mon6
# 10  Zacian (Hero of Many Battles)
# 9                       Primarina
# 8                       Dragonite
# 7                        Garchomp
# 6                        Genesect
# 5                         Snorlax
# 4                        Melmetal
# 3                          Mewtwo
# 2                         Snorlax
